# %%
import os 
import pandas as pd 
import json 
import sys 
import numpy as np

# %%
DATA_PATH = "../../data/trace-crs-chatbot/"
ORIGINAL_EXPORTS_PATH = DATA_PATH + "original_firestore_exports/"

with open(DATA_PATH + "merged/combined_collections_filtered.json") as f:
    data = json.load(f)

# %%
def get_user_choice(session):
    try:
        feedback = session['conversations'][0]['feedback_answers']
        for fb in feedback: 
            if fb["q_id"] == 0:
                return fb["answer"]
    except Exception as e:
        return None
    
    return None

# %%
def get_recs(session, baseline=False):
    if baseline:
        key = 'baseline_recommendation'
    else: 
        key = 'context_aware_recommendation'

    rec = session['cfe_responses'][0]['context'][key]
    if rec is None:
        return {
            'rec': None,
            'explanation': None
        }
    return {
        'rec': rec['recommendation'], 
        'explanation': rec['explanation']
    }

# %%
def get_shown_rec(session):
    return session['cfe_responses'][0]['recommendation_shown']

# %%
recs_combined = []

for session in data:
    try:
        ca_rec = get_recs(session, baseline=False)
        ba_rec = get_recs(session, baseline=True)
        result = {
            'session_id': session['session_id'],
            'user_choice': get_user_choice(session),
            'shown_rec': get_shown_rec(session),
            'context_aware_rec': ca_rec['rec'],
            'context_aware_explanation': ca_rec['explanation'],
            'baseline_rec': ba_rec['rec'],
            'baseline_explanation': ba_rec['explanation']
        }
        recs_combined.append(result)
    except Exception as e:
        print(f"Error processing session {session['session_id']}: {e}")
# Out:
# Error processing session 20260128_101415_869458: 'NoneType' object is not subscriptable
# Error processing session 20260122_205440_968054: list index out of range
# Error processing session 20260128_222315_849959: list index out of range
# Error processing session 20260201_151138_000293: list index out of range
# Error processing session 20260123_145540_135839: list index out of range
# Error processing session 20260129_084630_223031: list index out of range
# Error processing session 20260121_141722_775629: list index out of range
# Error processing session 20260129_084835_707171: list index out of range
# Error processing session 20260201_151040_801929: list index out of range
# Error processing session 20260126_130348_513307: list index out of range
# Error processing session 20260123_145454_553257: list index out of range
# Error processing session 20260201_152103_549729: list index out of range
# Error processing session 20260126_111518_494183: list index out of range
# Error processing session 20260126_105915_107334: list index out of range
# Error processing session 20260129_095533_433424: list index out of range
# Error processing session 20260201_151646_396817: list index out of range
# Error processing session 20260126_132350_879189: list index out of range
# Error processing session 20260201_151638_411625: list index out of range
# Error processing session 20260201_151015_262775: list index out of range
# Error processing session 20260201_151101_926959: list index out of range
# Error processing session 20260121_134503_724052: list index out of range
# Error processing session 20260129_084959_277458: list index out of range
# Error processing session 20260201_151333_492962: list index out of range
# Error processing session 20260129_084811_785941: list index out of range
# Error processing session 20260129_084902_551437: list index out of range
# Error processing session 20260121_141658_025445: list index out of range
# Error processing session 20260126_071701_332095: list index out of range
# Error processing session 20260123_191827_085163: list index out of range
# Error processing session 20260129_083820_369217: list index out of range
# Error processing session 20260201_151750_405062: list index out of range
# Error processing session 20260201_150923_164399: list index out of range
# Error processing session 20260201_144315_185243: list index out of range

# %%
rec_df = pd.DataFrame(recs_combined)

# %%
rec_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 75 entries, 0 to 74
# Data columns (total 7 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   session_id                 75 non-null     object
#  1   user_choice                53 non-null     object
#  2   shown_rec                  75 non-null     object
#  3   context_aware_rec          49 non-null     object
#  4   context_aware_explanation  49 non-null     object
#  5   baseline_rec               56 non-null     object
#  6   baseline_explanation       56 non-null     object
# dtypes: object(7)
# memory usage: 4.2+ KB

# %%
rec_df.head()
# Out:
#                session_id                  user_choice  shown_rec  \
# 0  20260126_131715_384614  1️⃣ Ljubljana (recommended)  Ljubljana
# 1  20260130_172226_892099       1️⃣ Graz (recommended)       Graz
# 2  20260121_140506_239613      1️⃣ Ibiza (recommended)      Ibiza
# 3  20260129_182052_049806                         None      Paris
# 4  20260129_125935_136152     2️⃣ Málaga (alternative)       Faro
#
#   context_aware_rec                          context_aware_explanation  \
# 0              None                                               None
# 1              Graz  Graz, a UNESCO World Heritage site and City of...
# 2              None                                               None
# 3            Krakow  Krakow offers a vibrant nightlife, excellent b...
# 4              Faro  Faro provides a serene yet engaging winter esc...
#
#   baseline_rec                               baseline_explanation
# 0         None                                               None
# 1       Vienna  Vienna is a renowned cultural capital, offerin...
# 2         None                                               None
# 3        Paris  Paris is recommended as a general leisure dest...
# 4       Málaga  Málaga offers a vibrant city experience with c...

# %%
rec_filter = rec_df[rec_df['user_choice'].notnull() & rec_df['shown_rec'].notnull()]

# %% [markdown]
# ### in how many sessions is the CA rec the same as the shown rec (from cfe)?

# %%
rec_ca = rec_df[rec_df['context_aware_rec'].notnull()]
rec_ca["ca_shown"] = [
    c2 in c1 if pd.notna(c1) and pd.notna(c2) else False
    for c1, c2 in zip(rec_ca["shown_rec"], rec_ca["context_aware_rec"])
]

rec_ca["ca_shown"].value_counts(normalize=True)
# Out:
# /var/folders/07/81pmlyln5szbq49h1zdqjq1h0000gn/T/ipykernel_32703/3612925385.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rec_ca["ca_shown"] = [
# ca_shown
# True     0.755102
# False    0.244898
# Name: proportion, dtype: float64

# %% [markdown]
# ### in those sessions where shown rec was NOT ca rec, how many times does the user still choose the alternative (i.e. ca rec)?

# %%
rec_not_ca = rec_ca[~rec_ca['ca_shown']]
rec_not_ca.head()
# Out:
#                 session_id                 user_choice shown_rec  \
# 3   20260129_182052_049806                        None     Paris
# 8   20260131_104028_599409                        None    Madrid
# 9   20260129_152850_188357    2️⃣ Warsaw (alternative)    Prague
# 10  20260126_185529_961407  1️⃣ Chamonix (recommended)  Chamonix
# 27  20260121_141441_436190    1️⃣ Madrid (recommended)    Madrid
#
#    context_aware_rec                          context_aware_explanation  \
# 3             Krakow  Krakow offers a vibrant nightlife, excellent b...
# 8             Lisbon  Lisbon offers a rich local culture and histori...
# 9             Warsaw  Warsaw offers a dynamic nightlife, a fascinati...
# 10         Innsbruck  Innsbruck provides excellent multi-day hiking ...
# 27           Seville  Seville provides a rich cultural experience wi...
#
#    baseline_rec                               baseline_explanation  ca_shown
# 3         Paris  Paris is recommended as a general leisure dest...     False
# 8        Madrid  Madrid is a popular European capital, known fo...     False
# 9        Prague  Prague is a highly popular and renowned Europe...     False
# 10     Chamonix  Chamonix is a premier destination for challeng...     False
# 27       Madrid  Madrid is a prime choice for a luxury cultural...     False

# %%
rec_not_ca["ca_chosen"] = [
    c2 in c1 if pd.notna(c1) and pd.notna(c2) else False
    for c1, c2 in zip(rec_not_ca["user_choice"], rec_not_ca["context_aware_rec"])
]
rec_not_ca["ca_chosen"].value_counts(normalize=True)
# Out:
# /var/folders/07/81pmlyln5szbq49h1zdqjq1h0000gn/T/ipykernel_32703/4169553919.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rec_not_ca["ca_chosen"] = [
# ca_chosen
# False    0.833333
# True     0.166667
# Name: proportion, dtype: float64

# %%
rec_filter.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 53 entries, 0 to 74
# Data columns (total 8 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   session_id                 53 non-null     object
#  1   user_choice                53 non-null     object
#  2   shown_rec                  53 non-null     object
#  3   context_aware_rec          34 non-null     object
#  4   context_aware_explanation  34 non-null     object
#  5   baseline_rec               39 non-null     object
#  6   baseline_explanation       39 non-null     object
#  7   ca_shown                   53 non-null     bool
# dtypes: bool(1), object(7)
# memory usage: 3.4+ KB

# %%
rec_ca_none = rec_filter[rec_filter['context_aware_rec'].isnull()]
rec_ca_none[rec_ca_none['baseline_rec'].notnull()].head()
# Out:
#                 session_id                   user_choice   shown_rec  \
# 32  20260126_183757_064706   2️⃣ Barcelona (alternative)      Krakow
# 40  20260126_185242_275306    1️⃣ Valencia (recommended)    Valencia
# 50  20260121_145705_751910  1️⃣ Copenhagen (recommended)  Copenhagen
#
#    context_aware_rec context_aware_explanation baseline_rec  \
# 32              None                      None    Barcelona
# 40              None                      None        Paris
# 50              None                      None        Paris
#
#                                  baseline_explanation
# 32  Barcelona is a vibrant city known for its stun...
# 40  Paris is a timeless choice for any traveler, o...
# 50  As no specific travel preferences were provide...

# %%
rec_filter["ca_chosen"] = [
    c2 in c1 if pd.notna(c1) and pd.notna(c2) else False
    for c1, c2 in zip(rec_filter["user_choice"], rec_filter["context_aware_rec"])
]
# Out:
# /var/folders/07/81pmlyln5szbq49h1zdqjq1h0000gn/T/ipykernel_32703/2035884000.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rec_filter["ca_chosen"] = [

# %%
rec_filter[(rec_filter['context_aware_rec'].notnull())]['ca_chosen'].value_counts(normalize=True)
# Out:
# ca_chosen
# True     0.617647
# False    0.382353
# Name: proportion, dtype: float64

# %%
ca_chosen_sessions = rec_filter[(rec_filter['context_aware_rec'].notnull()) & (rec_filter['ca_chosen'] == True)]['session_id'].tolist()

# %%
len(ca_chosen_sessions)
# Out:
# 21

# %% [markdown]
# ## get q3 answers for ca chosen sessions

# %%
q3_ans_dist = []
for session in data:
    if session['session_id'] not in ca_chosen_sessions:
        continue
    try:
        feedback = session['conversations'][0]['feedback_answers']
        for fb in feedback: 
            if fb["q_id"] == 3:
                q3_ans_dist.append(fb["answer"])
    except Exception as e:
        continue

# %%
q3_series = pd.Series(q3_ans_dist)
q3_series.value_counts(normalize=True)
# Out:
# ⚪⚪⚪⚪⚪ Not at all      0.266667
# ⚫⚪⚪⚪⚪ Slightly        0.266667
# ⚫⚫⚪⚪⚪ Moderately      0.266667
# ⚫⚫⚫⚫⚪ Strongly        0.133333
# ⭐️⭐️⭐️⭐️ Very well    0.066667
# Name: proportion, dtype: float64

# %%
b_chosen_sessions = rec_filter[(rec_filter['baseline_rec'].notnull()) & (rec_filter['ca_chosen'] == False)]['session_id'].tolist()

# %%
q3_ans_dist_b = []
for session in data:
    if session['session_id'] not in b_chosen_sessions:
        continue
    try:
        feedback = session['conversations'][0]['feedback_answers']
        for fb in feedback: 
            if fb["q_id"] == 3:
                q3_ans_dist_b.append(fb["answer"])
    except Exception as e:
        continue

# %%
q3_series_b = pd.Series(q3_ans_dist_b)
q3_series_b.value_counts(normalize=True)
# Out:
# ⚫⚫⚫⚫⚪ Strongly        0.333333
# ⚫⚫⚪⚪⚪ Moderately      0.200000
# ⚪⚪⚪⚪⚪ Not at all      0.200000
# ⭐️ Not at all         0.066667
# ⭐️⭐️⭐️ Moderately     0.066667
# ⚫⚪⚪⚪⚪ Slightly        0.066667
# ⭐️⭐️⭐️⭐️ Very well    0.066667
# Name: proportion, dtype: float64

# %% [markdown]
# ### get q4 feedback

# %%
q4_ans_dist = []
for session in data:
    try:
        feedback = session['conversations'][0]['feedback_answers']
        for fb in feedback: 
            if fb["q_id"] == 4:
                q4_ans_dist.append({
                    "session_id": session['session_id'],
                    "answer": fb["answer"]})
    except Exception as e:
        continue

# %%
q4_ans_dist
# Out:
# [{'session_id': '20260126_153942_188662',
#   'answer': "I really liked the experience, especially the clarifying questions, which are a great way to narrow down the search window (I wouldn't mind if it asked more questions). I also really liked that it gave the user profile it works with to the user. \nWhat I noticed is that it asked how flexible I am time-wise, but didn't give a time window with the suggestion when I said I was. Also it creates a new user profile for every new query (and asks the same questions/or similar). Also it could also ask questions about what i dont like about travel/ a specific location f.e. crowds, loud nightlife"},
#  {'session_id': '20260126_184758_853057', 'answer': 'skipped'},
#  {'session_id': '20260127_154111_084888',
#   'answer': 'maybe give some numerical data about, for example, costs for accomodation and travel, or like the mean cost of restaurants.'},
#  {'session_id': '20260128_101415_869458', 'answer': 'skipped'},
#  {'session_id': '20260129_095947_694631', 'answer': 'skipped'},
#  {'session_id': '20260121_140506_239613', 'answer': 'nope'},
#  {'session_id': '20260127_092431_664164', 'answer': 'skipped'},
#  {'session_id': '20260123_192019_714787', 'answer': 'skipped'},
#  {'session_id': '20260126_131944_135047', 'answer': 'skipped'},
#  {'session_id': '20260126_152627_749852', 'answer': 'skipped'},
#  {'session_id': '20260129_095818_822927', 'answer': 'skipped'},
#  {'session_id': '20260129_095640_247451', 'answer': 'skipped'},
#  {'session_id': '20260126_131715_384614', 'answer': 'skipped'},
#  {'session_id': '20260126_130348_513307',
#   'answer': 'Both optionsa were not great. I am n a bdget and Oslo is the most expensive capital in norther europe, copenhagen second most expensive....'},
#  {'session_id': '20260129_095352_611230', 'answer': 'skipped'},
#  {'session_id': '20260126_183757_064706',
#   'answer': 'Krakow in January might be a little cold'},
#  {'session_id': '20260129_085009_134868',
#   'answer': 'It would be better to ask for the starting city to make the question clearer. Also, I tried several times with almost the same question, and the system crashed.'},
#  {'session_id': '20260126_144311_441608', 'answer': 'sali'},
#  {'session_id': '20260129_094949_568826', 'answer': 'skipped'},
#  {'session_id': '20260126_184522_033512', 'answer': 'skipped'},
#  {'session_id': '20260126_184218_343121', 'answer': 'skipped'},
#  {'session_id': '20260126_185529_961407', 'answer': 'very good choice'},
#  {'session_id': '20260126_185242_275306', 'answer': 'skipped'},
#  {'session_id': '20260126_071153_792046', 'answer': 'skipped'},
#  {'session_id': '20260127_081054_034778', 'answer': 'skipped'},
#  {'session_id': '20260127_081605_510679', 'answer': 'skipped'},
#  {'session_id': '20260129_082651_834971',
#   'answer': 'Regarding the budget, I never mentioned that it should be low, but the agent assumed it. It would have been better to ask the user or at least clarify that this was an assumption based on some reasoning'},
#  {'session_id': '20260122_201220_430091', 'answer': 'skipped'},
#  {'session_id': '20260126_115249_875890', 'answer': 'skipped'},
#  {'session_id': '20260121_145705_751910',
#   'answer': 'all good, woudl have been nice to have some images of these cities and posisble places I cna go to'}]

# %% [markdown]
# ## get system latency

# %%
time_taken = []
for session in data:
    try: 
        cfe_response = session['cfe_responses'][0]
        time_taken_secs = cfe_response['time_taken_seconds']
        time_taken.append({
            "session_id": session['session_id'],
            "time_taken_seconds": time_taken_secs
        })
    except Exception as e:
        print("Error processing session {}: {}".format(session['session_id'], e))
        continue
# Out:
# Error processing session 20260126_105915_107334: list index out of range
# Error processing session 20260129_083820_369217: list index out of range
# Error processing session 20260121_141722_775629: list index out of range
# Error processing session 20260129_084811_785941: list index out of range
# Error processing session 20260129_084835_707171: list index out of range
# Error processing session 20260121_141658_025445: list index out of range
# Error processing session 20260121_134503_724052: list index out of range
# Error processing session 20260126_111518_494183: list index out of range
# Error processing session 20260122_205440_968054: list index out of range
# Error processing session 20260129_084630_223031: list index out of range
# Error processing session 20260126_132350_879189: list index out of range
# Error processing session 20260123_191827_085163: list index out of range
# Error processing session 20260126_130348_513307: list index out of range
# Error processing session 20260126_071701_332095: list index out of range
# Error processing session 20260129_084902_551437: list index out of range
# Error processing session 20260129_084959_277458: list index out of range
# Error processing session 20260123_145540_135839: list index out of range
# Error processing session 20260128_222315_849959: list index out of range
# Error processing session 20260129_095533_433424: list index out of range
# Error processing session 20260123_145454_553257: list index out of range

# %%
tts = pd.DataFrame(time_taken)
tts['time_taken_seconds'].describe()
# Out:
# count    52.000000
# mean     22.774992
# std       5.554101
# min      12.565411
# 25%      19.112859
# 50%      21.350383
# 75%      25.332189
# max      37.596892
# Name: time_taken_seconds, dtype: float64
